# %%
from ftplib import FTP
import os
from datetime import date, timedelta

def downloadFiles(destination, cutoff_year=2019, file_pattern='tif.gz'):
  folderlist = ftp.nlst()
  main_dir = ftp.pwd()
  for folder in folderlist:
    if int(folder) >= cutoff_year:
      ftp.cwd('{}/{}'.format(main_dir, folder))
      filelist = ftp.nlst()
      for file in filelist:
          if file_pattern in file:
              ftp.retrbinary("RETR " + file, open(os.path.join(destination,file),"wb").write)
              print(file + " downloaded")
  return

# %%
ftp = FTP('ftp.chg.ucsb.edu')
ftp.login(user='', passwd = '')
# Out:
# '230 Login successful.'

# %%
ftp.cwd('/pub/org/chg/products/CHIRPS-2.0/africa_daily/tifs/p05')
# Out:
# '250 Directory successfully changed.'

# %%
dest = os.path.join(os.getcwd(), 'rainfall', '2019')
dest
# Out:
# 'C:\\Users\\ATeklesadik\\OneDrive - Rode Kruis\\Documents\\documents\\ethiopia\\statistical_model\\input\\rainfall\\2019'

# %%
downloadFiles(dest)
ftp.quit()
# Out:
# chirps-v2.0.2019.01.01.tif.gz downloaded
# chirps-v2.0.2019.01.02.tif.gz downloaded
# chirps-v2.0.2019.01.03.tif.gz downloaded
# chirps-v2.0.2019.01.04.tif.gz downloaded
# chirps-v2.0.2019.01.05.tif.gz downloaded
# chirps-v2.0.2019.01.06.tif.gz downloaded
# chirps-v2.0.2019.01.07.tif.gz downloaded
# chirps-v2.0.2019.01.08.tif.gz downloaded
# chirps-v2.0.2019.01.09.tif.gz downloaded
# chirps-v2.0.2019.01.10.tif.gz downloaded
# chirps-v2.0.2019.01.11.tif.gz downloaded
# chirps-v2.0.2019.01.12.tif.gz downloaded
# chirps-v2.0.2019.01.13.tif.gz downloaded
# chirps-v2.0.2019.01.14.tif.gz downloaded
# chirps-v2.0.2019.01.15.tif.gz downloaded
# chirps-v2.0.2019.01.16.tif.gz downloaded
# chirps-v2.0.2019.01.17.tif.gz downloaded
# chirps-v2.0.2019.01.18.tif.gz downloaded
# chirps-v2.0.2019.01.19.tif.gz downloaded
# chirps-v2.0.2019.01.20.tif.gz downloaded
# chirps-v2.0.2019.01.21.tif.gz downloaded
# chirps-v2.0.2019.01.22.tif.gz downloaded
# chirps-v2.0.2019.01.23.tif.gz downloaded
# chirps-v2.0.2019.01.24.tif.gz downloaded
# chirps-v2.0.2019.01.25.tif.gz downloaded
# chirps-v2.0.2019.01.26.tif.gz downloaded
# chirps-v2.0.2019.01.27.tif.gz downloaded
# chirps-v2.0.2019.01.28.tif.gz downloaded
# chirps-v2.0.2019.01.29.tif.gz downloaded
# chirps-v2.0.2019.01.30.tif.gz downloaded
# chirps-v2.0.2019.01.31.tif.gz downloaded
# chirps-v2.0.2019.02.01.tif.gz downloaded
# chirps-v2.0.2019.02.02.tif.gz downloaded
# chirps-v2.0.2019.02.03.tif.gz downloaded
# chirps-v2.0.2019.02.04.tif.gz downloaded
# chirps-v2.0.2019.02.05.tif.gz downloaded
# chirps-v2.0.2019.02.06.tif.gz downloaded
# chirps-v2.0.2019.02.07.tif.gz downloaded
# chirps-v2.0.2019.02.08.tif.gz downloaded
# chirps-v2.0.2019.02.09.tif.gz downloaded
# chirps-v2.0.2019.02.10.tif.gz downloaded
# chirps-v2.0.2019.02.11.tif.gz downloaded
# chirps-v2.0.2019.02.12.tif.gz downloaded
# chirps-v2.0.2019.02.13.tif.gz downloaded
# chirps-v2.0.2019.02.14.tif.gz downloaded
# chirps-v2.0.2019.02.15.tif.gz downloaded
# chirps-v2.0.2019.02.16.tif.gz downloaded
# chirps-v2.0.2019.02.17.tif.gz downloaded
# chirps-v2.0.2019.02.18.tif.gz downloaded
# chirps-v2.0.2019.02.19.tif.gz downloaded
# chirps-v2.0.2019.02.20.tif.gz downloaded
# chirps-v2.0.2019.02.21.tif.gz downloaded
# chirps-v2.0.2019.02.22.tif.gz downloaded
# chirps-v2.0.2019.02.23.tif.gz downloaded
# chirps-v2.0.2019.02.24.tif.gz downloaded
# chirps-v2.0.2019.02.25.tif.gz downloaded
# chirps-v2.0.2019.02.26.tif.gz downloaded
# chirps-v2.0.2019.02.27.tif.gz downloaded
# chirps-v2.0.2019.02.28.tif.gz downloaded
# chirps-v2.0.2019.03.01.tif.gz downloaded
# chirps-v2.0.2019.03.02.tif.gz downloaded
# chirps-v2.0.2019.03.03.tif.gz downloaded
# chirps-v2.0.2019.03.04.tif.gz downloaded
# chirps-v2.0.2019.03.05.tif.gz downloaded
# chirps-v2.0.2019.03.06.tif.gz downloaded
# chirps-v2.0.2019.03.07.tif.gz downloaded
# chirps-v2.0.2019.03.08.tif.gz downloaded
# chirps-v2.0.2019.03.09.tif.gz downloaded
# chirps-v2.0.2019.03.10.tif.gz downloaded
# chirps-v2.0.2019.03.11.tif.gz downloaded
# chirps-v2.0.2019.03.12.tif.gz downloaded
# chirps-v2.0.2019.03.13.tif.gz downloaded
# chirps-v2.0.2019.03.14.tif.gz downloaded
# chirps-v2.0.2019.03.15.tif.gz downloaded
# chirps-v2.0.2019.03.16.tif.gz downloaded
# chirps-v2.0.2019.03.17.tif.gz downloaded
# chirps-v2.0.2019.03.18.tif.gz downloaded
# chirps-v2.0.2019.03.19.tif.gz downloaded
# chirps-v2.0.2019.03.20.tif.gz downloaded
# chirps-v2.0.2019.03.21.tif.gz downloaded
# chirps-v2.0.2019.03.22.tif.gz downloaded
# chirps-v2.0.2019.03.23.tif.gz downloaded
# chirps-v2.0.2019.03.24.tif.gz downloaded
# chirps-v2.0.2019.03.25.tif.gz downloaded
# chirps-v2.0.2019.03.26.tif.gz downloaded
# chirps-v2.0.2019.03.27.tif.gz downloaded
# chirps-v2.0.2019.03.28.tif.gz downloaded
# chirps-v2.0.2019.03.29.tif.gz downloaded
# chirps-v2.0.2019.03.30.tif.gz downloaded
# chirps-v2.0.2019.03.31.tif.gz downloaded
# chirps-v2.0.2019.04.01.tif.gz downloaded
# chirps-v2.0.2019.04.02.tif.gz downloaded
# chirps-v2.0.2019.04.03.tif.gz downloaded
# chirps-v2.0.2019.04.04.tif.gz downloaded
# chirps-v2.0.2019.04.05.tif.gz downloaded
# chirps-v2.0.2019.04.06.tif.gz downloaded
# chirps-v2.0.2019.04.07.tif.gz downloaded
# chirps-v2.0.2019.04.08.tif.gz downloaded
# chirps-v2.0.2019.04.09.tif.gz downloaded
# chirps-v2.0.2019.04.10.tif.gz downloaded
# chirps-v2.0.2019.04.11.tif.gz downloaded
# chirps-v2.0.2019.04.12.tif.gz downloaded
# chirps-v2.0.2019.04.13.tif.gz downloaded
# chirps-v2.0.2019.04.14.tif.gz downloaded
# chirps-v2.0.2019.04.15.tif.gz downloaded
# chirps-v2.0.2019.04.16.tif.gz downloaded
# chirps-v2.0.2019.04.17.tif.gz downloaded
# chirps-v2.0.2019.04.18.tif.gz downloaded
# chirps-v2.0.2019.04.19.tif.gz downloaded
# chirps-v2.0.2019.04.20.tif.gz downloaded
# chirps-v2.0.2019.04.21.tif.gz downloaded
# chirps-v2.0.2019.04.22.tif.gz downloaded
# chirps-v2.0.2019.04.23.tif.gz downloaded
# chirps-v2.0.2019.04.24.tif.gz downloaded
# chirps-v2.0.2019.04.25.tif.gz downloaded
# chirps-v2.0.2019.04.26.tif.gz downloaded
# chirps-v2.0.2019.04.27.tif.gz downloaded
# chirps-v2.0.2019.04.28.tif.gz downloaded
# chirps-v2.0.2019.04.29.tif.gz downloaded
# chirps-v2.0.2019.04.30.tif.gz downloaded
# chirps-v2.0.2019.05.01.tif.gz downloaded
# chirps-v2.0.2019.05.02.tif.gz downloaded
# chirps-v2.0.2019.05.03.tif.gz downloaded
# chirps-v2.0.2019.05.04.tif.gz downloaded
# chirps-v2.0.2019.05.05.tif.gz downloaded
# chirps-v2.0.2019.05.06.tif.gz downloaded
# chirps-v2.0.2019.05.07.tif.gz downloaded
# chirps-v2.0.2019.05.08.tif.gz downloaded
# chirps-v2.0.2019.05.09.tif.gz downloaded
# chirps-v2.0.2019.05.10.tif.gz downloaded
# chirps-v2.0.2019.05.11.tif.gz downloaded
# chirps-v2.0.2019.05.12.tif.gz downloaded
# chirps-v2.0.2019.05.13.tif.gz downloaded
# chirps-v2.0.2019.05.14.tif.gz downloaded
# chirps-v2.0.2019.05.15.tif.gz downloaded
# chirps-v2.0.2019.05.16.tif.gz downloaded
# chirps-v2.0.2019.05.17.tif.gz downloaded
# chirps-v2.0.2019.05.18.tif.gz downloaded
# chirps-v2.0.2019.05.19.tif.gz downloaded
# chirps-v2.0.2019.05.20.tif.gz downloaded
# chirps-v2.0.2019.05.21.tif.gz downloaded
# chirps-v2.0.2019.05.22.tif.gz downloaded
# chirps-v2.0.2019.05.23.tif.gz downloaded
# chirps-v2.0.2019.05.24.tif.gz downloaded
# chirps-v2.0.2019.05.25.tif.gz downloaded
# chirps-v2.0.2019.05.26.tif.gz downloaded
# chirps-v2.0.2019.05.27.tif.gz downloaded
# chirps-v2.0.2019.05.28.tif.gz downloaded
# chirps-v2.0.2019.05.29.tif.gz downloaded
# chirps-v2.0.2019.05.30.tif.gz downloaded
# chirps-v2.0.2019.05.31.tif.gz downloaded
# chirps-v2.0.2019.06.01.tif.gz downloaded
# chirps-v2.0.2019.06.02.tif.gz downloaded
# chirps-v2.0.2019.06.03.tif.gz downloaded
# chirps-v2.0.2019.06.04.tif.gz downloaded
# chirps-v2.0.2019.06.05.tif.gz downloaded
# chirps-v2.0.2019.06.06.tif.gz downloaded
# chirps-v2.0.2019.06.07.tif.gz downloaded
# chirps-v2.0.2019.06.08.tif.gz downloaded
# chirps-v2.0.2019.06.09.tif.gz downloaded
# chirps-v2.0.2019.06.10.tif.gz downloaded
# chirps-v2.0.2019.06.11.tif.gz downloaded
# chirps-v2.0.2019.06.12.tif.gz downloaded
# chirps-v2.0.2019.06.13.tif.gz downloaded
# chirps-v2.0.2019.06.14.tif.gz downloaded
# chirps-v2.0.2019.06.15.tif.gz downloaded
# chirps-v2.0.2019.06.16.tif.gz downloaded
# chirps-v2.0.2019.06.17.tif.gz downloaded
# chirps-v2.0.2019.06.18.tif.gz downloaded
# chirps-v2.0.2019.06.19.tif.gz downloaded
# chirps-v2.0.2019.06.20.tif.gz downloaded
# chirps-v2.0.2019.06.21.tif.gz downloaded
# chirps-v2.0.2019.06.22.tif.gz downloaded
# chirps-v2.0.2019.06.23.tif.gz downloaded
# chirps-v2.0.2019.06.24.tif.gz downloaded
# chirps-v2.0.2019.06.25.tif.gz downloaded
# chirps-v2.0.2019.06.26.tif.gz downloaded
# chirps-v2.0.2019.06.27.tif.gz downloaded
# chirps-v2.0.2019.06.28.tif.gz downloaded
# chirps-v2.0.2019.06.29.tif.gz downloaded
# chirps-v2.0.2019.06.30.tif.gz downloaded
# chirps-v2.0.2019.07.01.tif.gz downloaded
# chirps-v2.0.2019.07.02.tif.gz downloaded
# chirps-v2.0.2019.07.03.tif.gz downloaded
# chirps-v2.0.2019.07.04.tif.gz downloaded
# chirps-v2.0.2019.07.05.tif.gz downloaded
# chirps-v2.0.2019.07.06.tif.gz downloaded
# chirps-v2.0.2019.07.07.tif.gz downloaded
# chirps-v2.0.2019.07.08.tif.gz downloaded
# chirps-v2.0.2019.07.09.tif.gz downloaded
# chirps-v2.0.2019.07.10.tif.gz downloaded
# chirps-v2.0.2019.07.11.tif.gz downloaded
# chirps-v2.0.2019.07.12.tif.gz downloaded
# chirps-v2.0.2019.07.13.tif.gz downloaded
# chirps-v2.0.2019.07.14.tif.gz downloaded
# chirps-v2.0.2019.07.15.tif.gz downloaded
# chirps-v2.0.2019.07.16.tif.gz downloaded
# chirps-v2.0.2019.07.17.tif.gz downloaded
# chirps-v2.0.2019.07.18.tif.gz downloaded
# chirps-v2.0.2019.07.19.tif.gz downloaded
# chirps-v2.0.2019.07.20.tif.gz downloaded
# chirps-v2.0.2019.07.21.tif.gz downloaded
# chirps-v2.0.2019.07.22.tif.gz downloaded
# chirps-v2.0.2019.07.23.tif.gz downloaded
# chirps-v2.0.2019.07.24.tif.gz downloaded
# chirps-v2.0.2019.07.25.tif.gz downloaded
# chirps-v2.0.2019.07.26.tif.gz downloaded
# chirps-v2.0.2019.07.27.tif.gz downloaded
# chirps-v2.0.2019.07.28.tif.gz downloaded
# chirps-v2.0.2019.07.29.tif.gz downloaded
# chirps-v2.0.2019.07.30.tif.gz downloaded
# chirps-v2.0.2019.07.31.tif.gz downloaded
# chirps-v2.0.2019.08.01.tif.gz downloaded
# chirps-v2.0.2019.08.02.tif.gz downloaded
# chirps-v2.0.2019.08.03.tif.gz downloaded
# chirps-v2.0.2019.08.04.tif.gz downloaded
# chirps-v2.0.2019.08.05.tif.gz downloaded
# chirps-v2.0.2019.08.06.tif.gz downloaded
# chirps-v2.0.2019.08.07.tif.gz downloaded
# chirps-v2.0.2019.08.08.tif.gz downloaded
# chirps-v2.0.2019.08.09.tif.gz downloaded
# chirps-v2.0.2019.08.10.tif.gz downloaded
# chirps-v2.0.2019.08.11.tif.gz downloaded
# chirps-v2.0.2019.08.12.tif.gz downloaded
# chirps-v2.0.2019.08.13.tif.gz downloaded
# chirps-v2.0.2019.08.14.tif.gz downloaded
# chirps-v2.0.2019.08.15.tif.gz downloaded
# chirps-v2.0.2019.08.16.tif.gz downloaded
# chirps-v2.0.2019.08.17.tif.gz downloaded
# chirps-v2.0.2019.08.18.tif.gz downloaded
# chirps-v2.0.2019.08.19.tif.gz downloaded
# chirps-v2.0.2019.08.20.tif.gz downloaded
# chirps-v2.0.2019.08.21.tif.gz downloaded
# chirps-v2.0.2019.08.22.tif.gz downloaded
# chirps-v2.0.2019.08.23.tif.gz downloaded
# chirps-v2.0.2019.08.24.tif.gz downloaded
# chirps-v2.0.2019.08.25.tif.gz downloaded
# chirps-v2.0.2019.08.26.tif.gz downloaded
# chirps-v2.0.2019.08.27.tif.gz downloaded
# chirps-v2.0.2019.08.28.tif.gz downloaded
# chirps-v2.0.2019.08.29.tif.gz downloaded
# chirps-v2.0.2019.08.30.tif.gz downloaded
# chirps-v2.0.2019.08.31.tif.gz downloaded
# chirps-v2.0.2019.09.01.tif.gz downloaded
# chirps-v2.0.2019.09.02.tif.gz downloaded
# chirps-v2.0.2019.09.03.tif.gz downloaded
# chirps-v2.0.2019.09.04.tif.gz downloaded
# chirps-v2.0.2019.09.05.tif.gz downloaded
# chirps-v2.0.2019.09.06.tif.gz downloaded
# chirps-v2.0.2019.09.07.tif.gz downloaded
# chirps-v2.0.2019.09.08.tif.gz downloaded
# chirps-v2.0.2019.09.09.tif.gz downloaded
# chirps-v2.0.2019.09.10.tif.gz downloaded
# chirps-v2.0.2019.09.11.tif.gz downloaded
# chirps-v2.0.2019.09.12.tif.gz downloaded
# chirps-v2.0.2019.09.13.tif.gz downloaded
# chirps-v2.0.2019.09.14.tif.gz downloaded
# chirps-v2.0.2019.09.15.tif.gz downloaded
# chirps-v2.0.2019.09.16.tif.gz downloaded
# chirps-v2.0.2019.09.17.tif.gz downloaded
# chirps-v2.0.2019.09.18.tif.gz downloaded
# chirps-v2.0.2019.09.19.tif.gz downloaded
# chirps-v2.0.2019.09.20.tif.gz downloaded
# chirps-v2.0.2019.09.21.tif.gz downloaded
# chirps-v2.0.2019.09.22.tif.gz downloaded
# chirps-v2.0.2019.09.23.tif.gz downloaded
# chirps-v2.0.2019.09.24.tif.gz downloaded
# chirps-v2.0.2019.09.25.tif.gz downloaded
# chirps-v2.0.2019.09.26.tif.gz downloaded
# chirps-v2.0.2019.09.27.tif.gz downloaded
# chirps-v2.0.2019.09.28.tif.gz downloaded
# chirps-v2.0.2019.09.29.tif.gz downloaded
# chirps-v2.0.2019.09.30.tif.gz downloaded
# chirps-v2.0.2019.10.01.tif.gz downloaded
# chirps-v2.0.2019.10.02.tif.gz downloaded
# chirps-v2.0.2019.10.03.tif.gz downloaded
# chirps-v2.0.2019.10.04.tif.gz downloaded
# chirps-v2.0.2019.10.05.tif.gz downloaded
# chirps-v2.0.2019.10.06.tif.gz downloaded
# chirps-v2.0.2019.10.07.tif.gz downloaded
# chirps-v2.0.2019.10.08.tif.gz downloaded
# chirps-v2.0.2019.10.09.tif.gz downloaded
# chirps-v2.0.2019.10.10.tif.gz downloaded
# chirps-v2.0.2019.10.11.tif.gz downloaded
# chirps-v2.0.2019.10.12.tif.gz downloaded
# chirps-v2.0.2019.10.13.tif.gz downloaded
# chirps-v2.0.2019.10.14.tif.gz downloaded
# chirps-v2.0.2019.10.15.tif.gz downloaded
# chirps-v2.0.2019.10.16.tif.gz downloaded
# chirps-v2.0.2019.10.17.tif.gz downloaded
# chirps-v2.0.2019.10.18.tif.gz downloaded
# chirps-v2.0.2019.10.19.tif.gz downloaded
# chirps-v2.0.2019.10.20.tif.gz downloaded
# chirps-v2.0.2019.10.21.tif.gz downloaded
# chirps-v2.0.2019.10.22.tif.gz downloaded
# chirps-v2.0.2019.10.23.tif.gz downloaded
# chirps-v2.0.2019.10.24.tif.gz downloaded
# chirps-v2.0.2019.10.25.tif.gz downloaded
# chirps-v2.0.2019.10.26.tif.gz downloaded
# chirps-v2.0.2019.10.27.tif.gz downloaded
# chirps-v2.0.2019.10.28.tif.gz downloaded
# chirps-v2.0.2019.10.29.tif.gz downloaded
# chirps-v2.0.2019.10.30.tif.gz downloaded
# chirps-v2.0.2019.10.31.tif.gz downloaded
# chirps-v2.0.2019.11.01.tif.gz downloaded
# chirps-v2.0.2019.11.02.tif.gz downloaded
# chirps-v2.0.2019.11.03.tif.gz downloaded
# chirps-v2.0.2019.11.04.tif.gz downloaded
# chirps-v2.0.2019.11.05.tif.gz downloaded
# chirps-v2.0.2019.11.06.tif.gz downloaded
# chirps-v2.0.2019.11.07.tif.gz downloaded
# chirps-v2.0.2019.11.08.tif.gz downloaded
# chirps-v2.0.2019.11.09.tif.gz downloaded
# chirps-v2.0.2019.11.10.tif.gz downloaded
# chirps-v2.0.2019.11.11.tif.gz downloaded
# chirps-v2.0.2019.11.12.tif.gz downloaded
# chirps-v2.0.2019.11.13.tif.gz downloaded
# chirps-v2.0.2019.11.14.tif.gz downloaded
# chirps-v2.0.2019.11.15.tif.gz downloaded
# chirps-v2.0.2019.11.16.tif.gz downloaded
# chirps-v2.0.2019.11.17.tif.gz downloaded
# chirps-v2.0.2019.11.18.tif.gz downloaded
# chirps-v2.0.2019.11.19.tif.gz downloaded
# chirps-v2.0.2019.11.20.tif.gz downloaded
# chirps-v2.0.2019.11.21.tif.gz downloaded
# chirps-v2.0.2019.11.22.tif.gz downloaded
# chirps-v2.0.2019.11.23.tif.gz downloaded
# chirps-v2.0.2019.11.24.tif.gz downloaded
# chirps-v2.0.2019.11.25.tif.gz downloaded
# chirps-v2.0.2019.11.26.tif.gz downloaded
# chirps-v2.0.2019.11.27.tif.gz downloaded
# chirps-v2.0.2019.11.28.tif.gz downloaded
# chirps-v2.0.2019.11.29.tif.gz downloaded
# chirps-v2.0.2019.11.30.tif.gz downloaded
# chirps-v2.0.2019.12.01.tif.gz downloaded
# chirps-v2.0.2019.12.02.tif.gz downloaded
# chirps-v2.0.2019.12.03.tif.gz downloaded
# chirps-v2.0.2019.12.04.tif.gz downloaded
# chirps-v2.0.2019.12.05.tif.gz downloaded
# chirps-v2.0.2019.12.06.tif.gz downloaded
# chirps-v2.0.2019.12.07.tif.gz downloaded
# chirps-v2.0.2019.12.08.tif.gz downloaded
# chirps-v2.0.2019.12.09.tif.gz downloaded
# chirps-v2.0.2019.12.10.tif.gz downloaded
# chirps-v2.0.2019.12.11.tif.gz downloaded
# chirps-v2.0.2019.12.12.tif.gz downloaded
# chirps-v2.0.2019.12.13.tif.gz downloaded
# chirps-v2.0.2019.12.14.tif.gz downloaded
# chirps-v2.0.2019.12.15.tif.gz downloaded
# chirps-v2.0.2019.12.16.tif.gz downloaded
# chirps-v2.0.2019.12.17.tif.gz downloaded
# chirps-v2.0.2019.12.18.tif.gz downloaded
# chirps-v2.0.2019.12.19.tif.gz downloaded
# chirps-v2.0.2019.12.20.tif.gz downloaded
# chirps-v2.0.2019.12.21.tif.gz downloaded
# chirps-v2.0.2019.12.22.tif.gz downloaded
# chirps-v2.0.2019.12.23.tif.gz downloaded
# chirps-v2.0.2019.12.24.tif.gz downloaded
# chirps-v2.0.2019.12.25.tif.gz downloaded
# chirps-v2.0.2019.12.26.tif.gz downloaded
# chirps-v2.0.2019.12.27.tif.gz downloaded
# chirps-v2.0.2019.12.28.tif.gz downloaded
# chirps-v2.0.2019.12.29.tif.gz downloaded
# chirps-v2.0.2019.12.30.tif.gz downloaded
# chirps-v2.0.2019.12.31.tif.gz downloaded
# chirps-v2.0.2020.01.01.tif.gz downloaded
# chirps-v2.0.2020.01.02.tif.gz downloaded
# chirps-v2.0.2020.01.03.tif.gz downloaded
# chirps-v2.0.2020.01.04.tif.gz downloaded
# chirps-v2.0.2020.01.05.tif.gz downloaded
# chirps-v2.0.2020.01.06.tif.gz downloaded
# chirps-v2.0.2020.01.07.tif.gz downloaded
# chirps-v2.0.2020.01.08.tif.gz downloaded
# chirps-v2.0.2020.01.09.tif.gz downloaded
# chirps-v2.0.2020.01.10.tif.gz downloaded
# chirps-v2.0.2020.01.11.tif.gz downloaded
# chirps-v2.0.2020.01.12.tif.gz downloaded
# chirps-v2.0.2020.01.13.tif.gz downloaded
# chirps-v2.0.2020.01.14.tif.gz downloaded
# chirps-v2.0.2020.01.15.tif.gz downloaded
# chirps-v2.0.2020.01.16.tif.gz downloaded
# chirps-v2.0.2020.01.17.tif.gz downloaded
# chirps-v2.0.2020.01.18.tif.gz downloaded
# chirps-v2.0.2020.01.19.tif.gz downloaded
# chirps-v2.0.2020.01.20.tif.gz downloaded
# chirps-v2.0.2020.01.21.tif.gz downloaded
# chirps-v2.0.2020.01.22.tif.gz downloaded
